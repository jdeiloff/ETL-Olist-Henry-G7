# %% [markdown]
# # Requisitos

# %% [markdown]
# ## Instalación de librerías necesarias

# %%
# %pip install sqlalchemy
# %pip install PyMySQL
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
#   Using cached SQLAlchemy-1.4.39-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# ...
#   Using cached greenlet-1.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
# ...
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# ...
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# ...
# Python interpreter will be restarted.
# </div>

# %%
import pandas as pd
import numpy as np
import requests
from sqlalchemy import create_engine
import datetime as dt
import matplotlib.pyplot as plt
import plotly.express as px
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Conexión a base de datos para crear dataframes necesarios

# %%
engine = create_engine('mysql+pymysql://sojoclar:sojoclar@proyecto-grupal-henry.cy2mi1kbmfb7.us-east-2.rds.amazonaws.com:3306/mydb')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
customers = pd.read_sql_table('customers', engine)
geolocation=pd.read_sql_table('geolocation', engine)
order_items=pd.read_sql_table('order_items', engine)
order_payments=pd.read_sql_table('order_payments', engine)
order_reviews=pd.read_sql_table('order_reviews', engine)
orders=pd.read_sql_table('orders', engine)
products=pd.read_sql_table('products', engine)
sellers=pd.read_sql_table('sellers', engine)
product_category_name_translation=pd.read_sql_table('product_category_name_translation', engine)
calendar=pd.read_sql_table('calendar',engine)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
customers.to_csv('customers.csv',index=False)
geolocation.to_csv('geolocation.csv',index=False)
order_items.to_csv('order_items.csv',index=False)
order_payments.to_csv('order_payments.csv',index=False)
order_reviews.to_csv('order_reviews.csv',index=False)
orders.to_csv('orders.csv',index=False)
products.to_csv('products.csv',index=False)
sellers.to_csv('sellers.csv',index=False)
calendar.to_csv('calendar.csv',index=False)
product_category_name_translation.to_csv('product_category_name_translation.csv',index=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
products.show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# ...

# %%
order_reviews
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# ...

# %%
pagos
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>payment_type</th>
#       <th>payment_installments</th>
#       <th>payment_value</th>
#       <th>payment_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
# ...

# %%
orders
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
#       <th>order_approved_at</th>
#       <th>delivered_carrier_date</th>
#       <th>delivered_customer_date</th>
# ...

# %%
order_payments
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>payment_type</th>
#       <th>payment_installments</th>
#       <th>payment_value</th>
#       <th>payment_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
pagos =pd.merge(order_payments, orders , on='order_id', how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pagos['years']=pagos['purchase_timestamp'].dt.year
pagos['weekends']=pagos['purchase_timestamp'].dt.week
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-233544858683447&gt;:2: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#
# </div>

# %%
ventas_anio1=pd.DataFrame()
ventas_anio2=pd.DataFrame()
ventas_anio3=pd.DataFrame()
ventas_anio1=pagos[pagos['years']==2016]
ventas_anio2=pagos[pagos['years']==2017]
ventas_anio3=pagos[pagos['years']==2018]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pagos
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>payment_type</th>
#       <th>payment_installments</th>
#       <th>payment_value</th>
#       <th>payment_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
# ...

# %%
ventas_anio2=ventas_anio2.groupby('weekends').sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ventas_anio3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>payment_installments</th>
#       <th>payment_value</th>
#       <th>payment_id</th>
#       <th>years</th>
#     </tr>
#     <tr>
#       <th>weekends</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
pagos=pd.merge(pagos, products , on='product_id', how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# ...

# %%
pagos=pd.merge(pagos, orders , on='order_id', how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pagos.groupby('purchase_timestamp')['payment_value'].sum().sort_values()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: purchase_timestamp
# 2018-08-25 21:20:50        9.59
# 2017-09-13 19:13:20       10.07
# 2018-06-21 20:29:25       10.89
# 2018-06-22 13:11:10       11.56
# 2017-01-05 12:06:36       11.62
#                          ...
# 2017-05-24 18:14:34     6726.66
# 2018-07-25 18:10:17     6922.21
# 2017-02-12 20:37:36     6929.31
# 2018-07-15 14:49:44     7274.88
# 2017-09-29 15:24:52    13664.08
# Name: payment_value, Length: 98111, dtype: float64</div>

# %%
orders['purchase_timestamp'].sort_values().tail(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 30130   2018-09-06 14:50:07
# 65246   2018-09-06 18:45:47
# 13033   2018-09-10 17:51:25
# 52527   2018-09-11 16:45:54
# 10442   2018-09-12 15:32:16
# 91148   2018-09-13 09:56:12
# 73471   2018-09-17 17:21:16
# 92195   2018-09-20 13:54:16
# 35150   2018-09-25 11:59:18
# 52098   2018-09-26 08:40:15
# 22190   2018-09-29 09:13:03
# 37735   2018-10-01 15:30:09
# 62892   2018-10-03 18:55:29
# 68317   2018-10-16 20:16:02
# 6511    2018-10-17 17:30:18
# Name: purchase_timestamp, dtype: datetime64[ns]</div>

# %%
customers
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>zip_code_prefix</th>
#       <th>city</th>
#       <th>state</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>00012a2ce6f8dcda20d059ce98491703</td>
#       <td>6273</td>
# ...

# %%
df_exp=pd.merge(orders, order_reviews , on='order_id', how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp=pd.merge(df_exp, customers , on='customer_id', how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp=pd.merge(df_exp,order_items,on='order_id',how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp=pd.merge(df_exp,products,on='product_id',how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp=pd.merge(df_exp,product_category_name_translation,on='product_category_name',how='left')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[111]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
#       <th>order_approved_at</th>
#       <th>delivered_carrier_date</th>
#       <th>delivered_customer_date</th>
# ...

# %%
df_exp['product_category_name'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# ...

# %%
Region={'PR':'Sur','RS':'Sur','SC':'Sur','SP':'Sudeste','MG':'Sudeste','RJ':'Sudeste','ES':'Sudeste','MT':'Centro oeste', 'MS':'Centro oeste', 'GO':'Centro oeste' , 'DF':'Centro oeste',
 'AC':'Norte', 'AP':'Norte','AM':'Norte','PA':'Norte', 'RO':'Norte','RR':'Norte', 'TO':'Norte', 	
'AL':'Nordeste',
'BA':'Nordeste',
'CE':'Nordeste',
'MA':'Nordeste',
'PB':'Nordeste',
'PI':'Nordeste',
'PE':'Nordeste',
'RN':'Nordeste',
'SE':'Nordeste',}

def get_region(state):
    return Region[state]

df_exp['region'] = df_exp['state'].apply(get_region)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[115]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
#       <th>order_approved_at</th>
#       <th>delivered_carrier_date</th>
#       <th>delivered_customer_date</th>
# ...

# %%
df_exp[df_exp['product_id'].isnull()]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# ...

# %%
products
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>product_category_name</th>
#       <th>name_length</th>
#       <th>description_length</th>
#       <th>photos_quantity</th>
#       <th>weight_g</th>
#       <th>length_cm</th>
#       <th>height_cm</th>
# ...

# %%
productos = pd.merge(order_items,products,on='product_id',how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
productos = productos['product_category_name'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
productos = productos.reset_index()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
productos_top = productos.head(10)
productos_low = productos.tail(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fig = px.bar(x=productos_top.index,y=productos_top['product_category_name'],labels={'x':'Categoria del producto','y':'Cantidad de ordenes'},title='Productos mas Vendidos',height=600, width=700,color=productos_top['product_category_name'],color_continuous_scale=px.colors.sequential.Rainbow)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(x=productos_low['index'],y=productos_low['product_category_name'],labels={'x':'Categoria del producto','y':'Cantidad de ordenes'},title='Productos menos Vendidos',height=600, width=700,color=productos_low['product_category_name'],color_continuous_scale=px.colors.sequential.Rainbow)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
productos_top
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[76]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>product_category_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>cama_mesa_banho</td>
#       <td>11747</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>beleza_saude</td>
# ...

# %% [markdown]
# puntajes bajos por entrega

# %%
entrega = df_exp[df_exp['comment_message'].str.find('entrega')!= -1]
entrega_baja = entrega[entrega['review_score']<3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
entrega_baja
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[121]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
#       <th>order_approved_at</th>
#       <th>delivered_carrier_date</th>
#       <th>delivered_customer_date</th>
# ...

# %%
entrega_baja['region'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[135]: Sudeste         460
# Sur              86
# Nordeste         83
# Centro oeste     50
# Norte            15
# Name: region, dtype: int64</div>

# %% [markdown]
# ## Puntajes bajos en general

# %%
df_bajo= df_exp[df_exp['review_score']<3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_bajo['product_category_name'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: cama_mesa_banho                  1514
# beleza_saude                     1101
# informatica_acessorios           1046
# moveis_decoracao                 1004
# esporte_lazer                     976
#                                  ...
# la_cuisine                          2
# artes_e_artesanato                  2
# fashion_roupa_infanto_juvenil       1
# flores                              1
# seguros_e_servicos                  1
# Name: product_category_name, Length: 72, dtype: int64</div>

# %%
df_bajo['region'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: Sudeste         9201
# Sur             1791
# Nordeste        1704
# Centro oeste     811
# Norte            303
# Name: region, dtype: int64</div>

# %%
df_exp['region'].value_counts()
# Out:
# Out[13]: Sudeste         68436
# Sur             14179
# Nordeste         9414
# Centro oeste     5801
# Norte            1854
# Name: region, dtype: int64

# %%
ciudades_entregas =pd.DataFrame()
ciudades_entregas['totales']=df_exp['city'].value_counts()
ciudades_entregas['puntajes bajos'] = df_bajo['city'].value_counts()
ciudades_entregas['porcentaje']=ciudades_entregas['puntajes bajos']*100/ciudades_entregas['totales']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ciudades_entregas
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>totales</th>
#       <th>puntajes bajos</th>
#       <th>porcentaje</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>sao paulo</th>
#       <td>15444</td>
#       <td>1911.0</td>
#       <td>12.373737</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Puntajes bajos por región

# %%
region_entregas =pd.DataFrame()
region_entregas['totales']=df_exp['region'].value_counts()
region_entregas['Puntajes bajos'] = df_bajo['region'].value_counts()
region_entregas['Porcentaje de PB']=region_entregas['Puntajes bajos']*100/region_entregas['totales']
region_entregas['Puntajes bajos por entrega'] = entrega_baja['region'].value_counts()
region_entregas['Porcentajes de PN por entrega']=region_entregas['Puntajes bajos por entrega']*100/region_entregas['Puntajes bajos']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plt.style.use('ggplot')
region_entregas[['Porcentaje de PB','Porcentajes de PN por entrega']].plot(kind ='bar')
plt.ylabel('Porcentaje')
plt.xlabel('Región')
plt.title('Porcentaje de puntuaciones bajas por región')
plt.show()

# %%
colores= ['red','orange','yellow','green','blue']
region_entregas['Porcentaje de PB'].plot(kind='barh',color=colores)
plt.ylabel('Regiones')
plt.xlabel('Porcentaje de puntajes bajos')
plt.title('Puntuaciones bajas por region')
plt.show()

# %%
df_exp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[145]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
#       <th>order_approved_at</th>
#       <th>delivered_carrier_date</th>
#       <th>delivered_customer_date</th>
# ...

# %%
df_exp['dif_days']=(df_exp['estimated_delivery_date'] - df_exp['delivered_customer_date']).dt.days
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# promedio de flete por region

# %%
df_exp.groupby('region').mean('freight_value')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review_score</th>
#       <th>zip_code_prefix</th>
#       <th>product_quantity</th>
#       <th>price</th>
#       <th>freight_value</th>
#       <th>name_length</th>
#       <th>description_length</th>
#       <th>photos_quantity</th>
# ...

# %% [markdown]
# tiempos

# %%
df_exp['month']=df_exp['purchase_timestamp'].dt.month
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp.groupby('month').count()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
#       <th>order_approved_at</th>
#       <th>delivered_carrier_date</th>
#       <th>delivered_customer_date</th>
#       <th>estimated_delivery_date</th>
#       <th>review_id</th>
#       <th>review_score</th>
#       <th>...</th>
#       <th>city</th>
#       <th>state</th>
#       <th>region</th>
#       <th>dif_days</th>
#       <th>product_quantity</th>
#       <th>product_id</th>
#       <th>seller_id</th>
#       <th>shipping_limit_date</th>
#       <th>price</th>
#       <th>freight_value</th>
# ...

# %%
orders['month']=orders['purchase_timestamp'].dt.month
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
orders.groupby('month').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
#       <th>order_approved_at</th>
#       <th>delivered_carrier_date</th>
#       <th>delivered_customer_date</th>
# ...

# %%
del meses
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
meses = pd.DataFrame()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
meses = pd.DataFrame()
meses=orders.groupby('month').count()
meses.reset_index(inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plt.style.use('ggplot')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plt.plot(meses['month'],meses['order_id'])
plt.xlabel('Meses') # definir el nombre del eje X
plt.ylabel('Cantidad de ordenes') # definir el nombre del eje Y
plt.title('Ordenes por mes')
plt.show()

# %%
orders['hours']=orders['purchase_timestamp'].dt.hour
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
horas = pd.DataFrame()
horas=orders.groupby('hours').count()
horas.reset_index(inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plt.plot(horas['hours'],horas['order_id'])
plt.xlabel('Horas') # definir el nombre del eje X
plt.ylabel('Cantidad de ordenes') # definir el nombre del eje Y
plt.title('Ordenes por Hora')
plt.show()

# %%
df_exp['hours']=df_exp['purchase_timestamp'].dt.hour
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp.groupby('hours').count()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>order_status</th>
#       <th>purchase_timestamp</th>
#       <th>order_approved_at</th>
#       <th>delivered_carrier_date</th>
#       <th>delivered_customer_date</th>
#       <th>estimated_delivery_date</th>
#       <th>review_id</th>
#       <th>review_score</th>
#       <th>...</th>
#       <th>state</th>
#       <th>region</th>
#       <th>dif_days</th>
#       <th>product_quantity</th>
#       <th>product_id</th>
#       <th>seller_id</th>
#       <th>shipping_limit_date</th>
#       <th>price</th>
#       <th>freight_value</th>
#       <th>month</th>
# ...

# %%
df_exp['region'].value_counts()
# Out:
# Out[40]: Sudeste         68436
# Sur             14179
# Nordeste         9414
# Centro oeste     5801
# Norte            1854
# Name: region, dtype: int64

# %%
m_sudeste=df_exp['region']=='Sudeste'
m_norte=df_exp['region']=='Norte'
m_sur=df_exp['region']=='Sur'
m_nordeste=df_exp['region']=='Nordeste'
m_centro=df_exp['region']=='Centro oeste'

# %%
df_exp[m_sudeste]['month'].value_counts().sort_values(ascending=False)
# Out:
# Out[51]: 8     7679
# 5     7385
# 7     7005
# 3     6786
# 6     6528
# 4     6395
# 2     5809
# 1     5483
# 11    5191
# 12    3956
# 10    3345
# 9     2874
# Name: month, dtype: int64

# %%
df_exp[m_nordeste]['month'].value_counts().sort_values(ascending=False)
# Out:
# Out[50]: 7     1104
# 5      953
# 3      936
# 4      910
# 8      902
# 6      841
# 2      779
# 1      745
# 11     702
# 12     541
# 10     523
# 9      478
# Name: month, dtype: int64

# %%
dtale.show(df_exp)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-07-18 21:30:51,936 - WARNING  - Found pyspark version &#34;3.2.1&#34; installed. The pyspark version 3.2 and above has a built-in &#34;pandas APIs on Spark&#34; module ported from Koalas. Try `import pyspark.pandas as ps` instead.
# 2022-07-18 21:30:53,873 - INFO     - Received command c on object id p0
# 2022-07-18 21:30:53,873 - INFO     - Received command c on object id p0
# 2022-07-18 21:30:53,874 - INFO     - Received command c on object id p0
# 2022-07-18 21:30:53,875 - INFO     - Received command c on object id p0
# 2022-07-18 21:30:53,879 - INFO     - Received command c on object id p0
# ...

# %%
#Clasificación categórica según n° de fotos disponibles por producto ordenado.

products.info()
print(products['photos_quantity'].unique())

products['photos_quantity']=products['photos_quantity'].fillna(0)

products['fotos_incluidas'] = products['photos_quantity'].apply(lambda x : 'Sin foto' if x == 0 else( 'Foto unica' if x == 1  else('Varias fotos' if x <= 3  else 'Muchas fotos')))

data_fotos= pd.merge(products,order_items,on='product_id',how='inner')
data_fotos.info()
#Borrado de columnas irrelevantes
data_fotos.drop(columns=['seller_id','shipping_limit_date','name_length','description_length','weight_g','length_cm','height_cm','width_cm','freight_value'],inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32341 non-null  object
#  2   name_length            32341 non-null  float64
#  3   description_length     32341 non-null  float64
#  4   photos_quantity        32341 non-null  float64
#  5   weight_g               32949 non-null  float64
#  6   length_cm              32949 non-null  float64
# ...

# %%
#Demostración de la cantidad de órdenes de productos para cada categoría de n° de fotos.
data_fotos['fotos_incluidas'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: Foto unica      59769
# Varias fotos    37499
# Muchas fotos    23186
# Sin foto         1758
# Name: fotos_incluidas, dtype: int64</div>

# %%
data_fotos_grafica = data_fotos['fotos_incluidas'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_fotos_graficas = data_fotos_grafica.reset_index()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_fotos_graficas
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>fotos_incluidas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Foto unica</td>
#       <td>59769</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Varias fotos</td>
# ...

# %%
data_fotos_graficas['fotos_incluidas']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 0    59769
# 1    37499
# 2    23186
# 3     1758
# Name: fotos_incluidas, dtype: int64</div>

# %%
desfase = (0, 0, 0, 0.1)
plt.pie(data_fotos_graficas['fotos_incluidas'], labels=data_fotos_graficas['index'], autopct="%0.1f %%",explode=desfase)
plt.axis("equal")
plt.title("Cantidad de fotos VS ventas")
plt.show()

# %%
sin_fotos= data_fotos[data_fotos['fotos_incluidas']=='Sin foto']
sin_fotos['product_category_name'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: Series([], Name: product_category_name, dtype: int64)</div>

# %%
Foto_unica= data_fotos[data_fotos['fotos_incluidas']=='Foto unica']
Foto_unica['product_category_name'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: cama_mesa_banho                  6818
# beleza_saude                     5630
# esporte_lazer                    4195
# informatica_acessorios           3891
# moveis_decoracao                 2744
#                                  ...
# artes_e_artesanato                  5
# fashion_esporte                     5
# fashion_calcados                    4
# fashion_roupa_infanto_juvenil       1
# seguros_e_servicos                  1
# Name: product_category_name, Length: 71, dtype: int64</div>

# %%
Varias_fotos= data_fotos[data_fotos['fotos_incluidas']=='Varias fotos']
Varias_fotos['product_category_name'].sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: relogios_presentes                          2609
# beleza_saude                                2132
# informatica_acessorios                      2042
# ferramentas_jardim                          2031
# moveis_decoracao                            1968
#                                             ...
# pc_gamer                                       2
# livros_importados                              2
# casa_conforto_2                                1
# portateis_cozinha_e_preparadores_de_alim       1
# la_cuisine                                     1
# Name: product_category_name, Length: 72, dtype: int64</div>

# %%
Muchas_fotos= data_fotos[data_fotos['fotos_incluidas']=='Muchas fotos']
Muchas_fotos['product_category_name'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: esporte_lazer                    1642
# moveis_decoracao                 1622
# telefonia                        1413
# utilidades_domesticas            1260
# relogios_presentes               1182
#                                  ...
# fashion_roupa_infanto_juvenil       2
# moveis_colchao_e_estofado           2
# livros_tecnicos                     2
# fraldas_higiene                     2
# seguros_e_servicos                  1
# Name: product_category_name, Length: 69, dtype: int64</div>
