# %% [markdown]
# # Requisitos

# %% [markdown]
# ## Instalación de librerias necesarias

# %%
# !pip install googletrans
# !pip install PyMySQL
# !pip install deep_translator
# !pip install boto3
# !pip install sqlalchemy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 5.8 MB/s
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.8/site-packages (from httpx==0.13.3-&gt;googletrans) (2020.12.5)
# Requirement already satisfied: idna==2.* in /databricks/python3/lib/python3.8/site-packages (from httpx==0.13.3-&gt;googletrans) (2.10)
# Collecting hstspreload
#   Downloading hstspreload-2022.7.10-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 27.9 MB/s
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 15.8 MB/s
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.7 MB/s
# Collecting rfc3986&lt;2,&gt;=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting h11&lt;0.10,&gt;=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.6 MB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 5.7 MB/s
# Collecting hpack&lt;4,&gt;=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Collecting hyperframe&lt;6,&gt;=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
# done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15734 sha256=2dca154d2a5ef156dafd387f7c432d667f23a762d9bc92e23999be63f8bda5b3
#   Stored in directory: /root/.cache/pip/wheels/0e/ce/9b/d51de1064911d42480ab6b57fc943ee36572441f27546354e2
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, chardet, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
# Successfully installed chardet-3.0.4 googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2022.7.10 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Collecting PyMySQL
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 3.3 MB/s
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.0.2
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Collecting deep_translator
#   Downloading deep_translator-1.8.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests&lt;3.0.0,&gt;=2.23.0 in /databricks/python3/lib/python3.8/site-packages (from deep_translator) (2.25.1)
# Collecting beautifulsoup4&lt;5.0.0,&gt;=4.9.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 28.7 MB/s
# Collecting soupsieve&gt;1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3.0.0,&gt;=2.23.0-&gt;deep_translator) (2020.12.5)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3.0.0,&gt;=2.23.0-&gt;deep_translator) (3.0.4)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3.0.0,&gt;=2.23.0-&gt;deep_translator) (1.25.11)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3.0.0,&gt;=2.23.0-&gt;deep_translator) (2.10)
# Installing collected packages: soupsieve, beautifulsoup4, deep-translator
# Successfully installed beautifulsoup4-4.11.1 deep-translator-1.8.3 soupsieve-2.3.2.post1
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Requirement already satisfied: boto3 in /databricks/python3/lib/python3.8/site-packages (1.16.7)
# Requirement already satisfied: jmespath&lt;1.0.0,&gt;=0.7.1 in /databricks/python3/lib/python3.8/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: botocore&lt;1.20.0,&gt;=1.19.7 in /databricks/python3/lib/python3.8/site-packages (from boto3) (1.19.7)
# Requirement already satisfied: s3transfer&lt;0.4.0,&gt;=0.3.0 in /databricks/python3/lib/python3.8/site-packages (from boto3) (0.3.7)
# Requirement already satisfied: python-dateutil&lt;3.0.0,&gt;=2.1 in /databricks/python3/lib/python3.8/site-packages (from botocore&lt;1.20.0,&gt;=1.19.7-&gt;boto3) (2.8.1)
# Requirement already satisfied: urllib3&lt;1.26,&gt;=1.25.4 in /databricks/python3/lib/python3.8/site-packages (from botocore&lt;1.20.0,&gt;=1.19.7-&gt;boto3) (1.25.11)
# Requirement already satisfied: six&gt;=1.5 in /databricks/python3/lib/python3.8/site-packages (from python-dateutil&lt;3.0.0,&gt;=2.1-&gt;botocore&lt;1.20.0,&gt;=1.19.7-&gt;boto3) (1.15.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.39-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 22.1 MB/s
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#      |████████████████████████████████| 156 kB 51.9 MB/s
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-1.1.2 sqlalchemy-1.4.39
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.2 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# </div>

# %% [markdown]
# ## Importación de librerías necesarias

# %%
import pandas as pd
import numpy as np
import requests
from googletrans import Translator
from sqlalchemy import create_engine
from deep_translator import GoogleTranslator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Ingesta de datos

# %% [markdown]
# ## Descarga de datasets en el entorno de Colaboratory

# %%
def import_data_files():
  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_closed_deals_dataset.csv?raw=true')
  with open('./olist_closed_deals_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_customers_dataset.csv?raw=true')
  with open('./olist_customers_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_geolocation_dataset.csv?raw=true')
  with open('./olist_geolocation_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_marketing_qualified_leads_dataset.csv?raw=true')
  with open('./olist_marketing_qualified_leads_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_order_items_dataset.csv?raw=true')
  with open('./olist_order_items_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_order_payments_dataset.csv?raw=true')
  with open('./olist_order_payments_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_order_reviews_dataset.csv?raw=true')
  with open('./olist_order_reviews_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/product_category_name_translation.csv?raw=true')
  with open('./product_category_name_translation.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_sellers_dataset.csv?raw=true')
  with open('./olist_sellers_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_products_dataset.csv?raw=true')
  with open('./olist_products_dataset.csv', 'wb') as f:
    f.write(r.content)

  r = requests.get('https://github.com/arielgmna/Proyecto_grupal_olist/blob/main/Datasets/olist_orders_dataset.csv?raw=true')
  with open('./olist_orders_dataset.csv', 'wb') as f:
    f.write(r.content)

  
import_data_files()
print("Los datasets fueron cargados satisfactoriamente")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Los datasets fueron cargados satisfactoriamente
# </div>

# %% [markdown]
# ## Creación de dataframes a partir de los archivos .csv normalizando columnas

# %%
customers = pd.read_csv('./olist_customers_dataset.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
geolocation = pd.read_csv('./olist_geolocation_dataset.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_items = pd.read_csv('./olist_order_items_dataset.csv', parse_dates=['shipping_limit_date'], infer_datetime_format=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_payments = pd.read_csv('./olist_order_payments_dataset.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_reviews = pd.read_csv('./olist_order_reviews_dataset.csv', parse_dates=['review_creation_date','review_answer_timestamp'], infer_datetime_format=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
orders = pd.read_csv('./olist_orders_dataset.csv', parse_dates=['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date'], infer_datetime_format=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
products = pd.read_csv('./olist_products_dataset.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sellers = pd.read_csv('./olist_sellers_dataset.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
product_category_name_translation = pd.read_csv('./product_category_name_translation.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Limpieza y normalización

# %% [markdown]
# ## Eliminación de columnas innecesarias

# %%
order_payments = order_payments.drop(columns='payment_sequential')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_payments
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[795]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>payment_type</th>
#       <th>payment_installments</th>
#       <th>payment_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b81ef226f3fe1789b1e8b2acac839d17</td>
#       <td>credit_card</td>
#       <td>8</td>
#       <td>99.33</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a9810da82917af2d9aefd1278f1dcfa0</td>
#       <td>credit_card</td>
#       <td>1</td>
#       <td>24.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>25e8ea4e93396b6fa0d3dd708e76c1bd</td>
#       <td>credit_card</td>
#       <td>1</td>
#       <td>65.71</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ba78997921bbcdc1373bb41e913ab953</td>
#       <td>credit_card</td>
#       <td>8</td>
#       <td>107.78</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>42fdf880ba16b47b59251dd489d4441a</td>
#       <td>credit_card</td>
#       <td>2</td>
#       <td>128.45</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>103881</th>
#       <td>0406037ad97740d563a178ecc7a2075c</td>
#       <td>boleto</td>
#       <td>1</td>
#       <td>363.31</td>
#     </tr>
#     <tr>
#       <th>103882</th>
#       <td>7b905861d7c825891d6347454ea7863f</td>
#       <td>credit_card</td>
#       <td>2</td>
#       <td>96.80</td>
#     </tr>
#     <tr>
#       <th>103883</th>
#       <td>32609bbb3dd69b3c066a6860554a77bf</td>
#       <td>credit_card</td>
#       <td>1</td>
#       <td>47.77</td>
#     </tr>
#     <tr>
#       <th>103884</th>
#       <td>b8b61059626efa996a60be9bb9320e10</td>
#       <td>credit_card</td>
#       <td>5</td>
#       <td>369.54</td>
#     </tr>
#     <tr>
#       <th>103885</th>
#       <td>28bbae6599b09d39ca406b747b6632b1</td>
#       <td>boleto</td>
#       <td>1</td>
#       <td>191.58</td>
#     </tr>
#   </tbody>
# </table>
# <p>103886 rows × 4 columns</p>
# </div>

# %%
customers = customers.drop('customer_unique_id', axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Renombrar columnas

# %%
customers = customers.rename(columns={'customer_zip_code_prefix':'zip_code_prefix', 'customer_city':'city', 'customer_state':'state'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
geolocation = geolocation.rename(columns={'geolocation_zip_code_prefix':'zip_code_prefix', 'geolocation_city':'city', 'geolocation_state':'state', 'geolocation_lat':'latitude', 'geolocation_lng':'longitude'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_reviews = order_reviews.rename(columns={'review_comment_message':'comment_message', 'review_creation_date':'creation_date', 'review_comment_title':'comment_title', 'review_answer_timestamp':'answer_timestamp'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_items = order_items.rename(columns={'order_item_id':'product_quantity'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sellers = sellers.rename(columns={'seller_zip_code_prefix':'zip_code_prefix', 'seller_city':'city', 'seller_state':'state'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
orders = orders.rename(columns={'order_purchase_timestamp':'purchase_timestamp', 'order_delivered_carrier_date':'delivered_carrier_date', 'order_delivered_customer_date':'delivered_customer_date', 'order_estimated_delivery_date':'estimated_delivery_date'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
products = products.rename(columns={'product_description_lenght':'description_length', 'product_name_lenght':'name_length', 'product_weight_g':'weight_g', 'product_length_cm':'length_cm', 'product_height_cm':'height_cm', 'product_width_cm':'width_cm', 'product_photos_qty':'photos_quantity'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Eliminación de duplicados

# %%
order_items = order_items.drop_duplicates('order_id', keep='last')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_reviews = order_reviews.drop_duplicates(subset='review_id', keep='first')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
geolocation=geolocation.drop_duplicates(subset='zip_code_prefix', keep='first')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Normalización de caracteres

# %%
geolocation['city']=geolocation['city'].str.replace('ã','a')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Completar valores nulos

# %%
order_reviews['comment_message'].fillna('sem_comentarios',inplace=True)
order_reviews['comment_title'].fillna('sem_titulo',inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Generación de nuevas columnas

# %%
order_payments = order_payments.reset_index()
order_payments = order_payments.rename(columns={'index':'payment_id'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_payments.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[810]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>payment_id</th>
#       <th>order_id</th>
#       <th>payment_type</th>
#       <th>payment_installments</th>
#       <th>payment_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>b81ef226f3fe1789b1e8b2acac839d17</td>
#       <td>credit_card</td>
#       <td>8</td>
#       <td>99.33</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>a9810da82917af2d9aefd1278f1dcfa0</td>
#       <td>credit_card</td>
#       <td>1</td>
#       <td>24.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>25e8ea4e93396b6fa0d3dd708e76c1bd</td>
#       <td>credit_card</td>
#       <td>1</td>
#       <td>65.71</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>ba78997921bbcdc1373bb41e913ab953</td>
#       <td>credit_card</td>
#       <td>8</td>
#       <td>107.78</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>42fdf880ba16b47b59251dd489d4441a</td>
#       <td>credit_card</td>
#       <td>2</td>
#       <td>128.45</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Creación de una nueva columna en español para las sucursales latinoamericanas

# %%
# creamos el objeto que nos permitirá hacer la traducción
translator = GoogleTranslator(source="en", target="es")

# Usamos el método apply de las series en pandas para aplicar a cada valor de la serie una función.
# Esta función será el método translate del objeto translator.
# Luego, reemplazamos la columna original por la modificada
product_category_name_translation['product_category_name_spanish'] = product_category_name_translation.product_category_name_english.apply(translator.translate)

print(product_category_name_translation)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">            product_category_name  ... product_category_name_spanish
# 0                    beleza_saude  ...               Salud y Belleza
# 1          informatica_acessorios  ...        ordenadores_accesorios
# 2                      automotivo  ...                          auto
# 3                 cama_mesa_banho  ...                cama_baño_mesa
# 4                moveis_decoracao  ...         decoración_de_muebles
# ..                            ...  ...                           ...
# 66                         flores  ...                        flores
# 67             artes_e_artesanato  ...             artes_y_artesanía
# 68                fraldas_higiene  ...             pañales_e_higiene
# 69  fashion_roupa_infanto_juvenil  ...            moda_ropa_infantil
# 70             seguros_e_servicos  ...         seguridad_y_servicios
#
# [71 rows x 3 columns]
# </div>

# %% [markdown]
# ## Creación de la columna 'region' en el dataframe 'geolocation'

# %%
Region={'PR':'Sur','RS':'Sur','SC':'Sur','SP':'Sudeste','MG':'Sudeste','RJ':'Sudeste','ES':'Sudeste','MT':'Centro oeste', 'MS':'Centro oeste', 'GO':'Centro oeste' , 'DF':'Centro oeste',
 'AC':'Norte', 'AP':'Norte','AM':'Norte','PA':'Norte', 'RO':'Norte','RR':'Norte', 'TO':'Norte', 	
'AL':'Nordeste',
'BA':'Nordeste',
'CE':'Nordeste',
'MA':'Nordeste',
'PB':'Nordeste',
'PI':'Nordeste',
'PE':'Nordeste',
'RN':'Nordeste',
'SE':'Nordeste',}

def get_region(state):
    return Region[state]

geolocation['region'] = geolocation['state'].apply(get_region)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Creación de una tabla Calendario

# %%
# Obtiene los días de las semana (en inglés)
days_names = {
        i: name
        for i, name
        in enumerate(['Monday', 'Tuesday', 'Wednesday',
                      'Thursday', 'Friday', 'Saturday', 
                      'Sunday'])}

def create_calendar_table(start='1990-01-01', end='2080-12-31'):
   df = pd.DataFrame({"date": pd.date_range(start, end)})
   df["week_day"] = df.date.dt.dayofweek.map(days_names.get)
   df["day"] = df.date.dt.day
   df["month"] = df.date.dt.month
   df["week"] = df.date.dt.isocalendar().week
   df["quarter"] = df.date.dt.quarter
   df["year"] = df.date.dt.year
   df.insert(0, 'date_id', (df.year.astype(str) + df.month.astype(str).str.zfill(2) + df.day.astype(str).str.zfill(2)).astype(int))
   return df

calendario = create_calendar_table('2016-01-01', '2019-12-31')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Análisis preliminar de datos

# %% [markdown]
# ## Relacionamos los puntajes malos(menores a 3 puntos) dados por los clientes, a problemas en la entrega eficiente de los productos. </h2>

# %%
order_reviews[order_reviews['review_score']<3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[814]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review_id</th>
#       <th>order_id</th>
#       <th>review_score</th>
#       <th>comment_title</th>
#       <th>comment_message</th>
#       <th>creation_date</th>
#       <th>answer_timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>15197aa66ff4d0650b5434f1b46cda19</td>
#       <td>b18dcdf73be66366873cd26c5724d1dc</td>
#       <td>1</td>
#       <td>sem_titulo</td>
#       <td>sem_comentarios</td>
#       <td>2018-04-13</td>
#       <td>2018-04-16 00:39:37</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>9314d6f9799f5bfba510cc7bcd468c01</td>
#       <td>0dacf04c5ad59fd5a0cc1faa07c34e39</td>
#       <td>2</td>
#       <td>sem_titulo</td>
#       <td>GOSTARIA DE SABER O QUE HOUVE, SEMPRE RECEBI E...</td>
#       <td>2018-01-18</td>
#       <td>2018-01-20 21:25:45</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>373cbeecea8286a2b66c97b1b157ec46</td>
#       <td>583174fbe37d3d5f0d6661be3aad1786</td>
#       <td>1</td>
#       <td>Não chegou meu produto</td>
#       <td>Péssimo</td>
#       <td>2018-08-15</td>
#       <td>2018-08-15 04:10:37</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>2c5e27fc178bde7ac173c9c62c31b070</td>
#       <td>0ce9a24111d850192a933fcaab6fbad3</td>
#       <td>1</td>
#       <td>sem_titulo</td>
#       <td>Não gostei ! Comprei gato por lebre</td>
#       <td>2017-12-13</td>
#       <td>2017-12-16 07:14:07</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>58044bca115705a48fe0e00a21390c54</td>
#       <td>68e55ca79d04a79f20d4bfc0146f4b66</td>
#       <td>1</td>
#       <td>sem_titulo</td>
#       <td>Sempre compro pela Internet e a entrega ocorre...</td>
#       <td>2018-04-08</td>
#       <td>2018-04-09 12:22:39</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>99174</th>
#       <td>cf0b8c06ba024a8a8d3f2ac51fcd99f4</td>
#       <td>fff2cdc825f9fc0ba3c04227cfa02303</td>
#       <td>2</td>
#       <td>sem_titulo</td>
#       <td>sem_comentarios</td>
#       <td>2018-03-09</td>
#       <td>2018-04-23 17:52:49</td>
#     </tr>
#     <tr>
#       <th>99184</th>
#       <td>6cf47345d15e054dd6df872e929bdb27</td>
#       <td>54e6829fe81bc86cf88b12e6d07ea298</td>
#       <td>1</td>
#       <td>sem_titulo</td>
#       <td>sem_comentarios</td>
#       <td>2017-06-08</td>
#       <td>2017-06-08 22:52:39</td>
#     </tr>
#     <tr>
#       <th>99200</th>
#       <td>2ee221b28e5b6fceffac59487ed39348</td>
#       <td>f2d12dd37eaef72ed7b1186b2edefbcd</td>
#       <td>2</td>
#       <td>Foto enganosa</td>
#       <td>Foto muito diferente principalmente a graninha...</td>
#       <td>2018-03-28</td>
#       <td>2018-05-25 01:23:26</td>
#     </tr>
#     <tr>
#       <th>99203</th>
#       <td>5085bc489aa6b58a29c4f922d59ff826</td>
#       <td>18ed848509774f56cc8c1c0a1903ad7f</td>
#       <td>2</td>
#       <td>sem_titulo</td>
#       <td>Tive um problema na entrega em que o correio c...</td>
#       <td>2018-02-21</td>
#       <td>2018-02-23 11:43:12</td>
#     </tr>
#     <tr>
#       <th>99223</th>
#       <td>efe49f1d6f951dd88b51e6ccd4cc548f</td>
#       <td>90531360ecb1eec2a1fbb265a0db0508</td>
#       <td>1</td>
#       <td>sem_titulo</td>
#       <td>meu produto chegou e ja tenho que devolver, po...</td>
#       <td>2017-07-03</td>
#       <td>2017-07-03 21:01:49</td>
#     </tr>
#   </tbody>
# </table>
# <p>14396 rows × 7 columns</p>
# </div>

# %%
entrega = order_reviews[order_reviews['comment_message'].str.find('entrega')!= -1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
entrega_baja = entrega[entrega['review_score']<3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Creación de la base de datos en MySQL hospedada en Amazon RDS

# %%
# Creación de la conexión con la base de datos en Amazon RDS
engine = create_engine(<connection_details>)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
customers.to_sql('customers', index=False, index_label='customer_id', con=engine, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
geolocation.to_sql('geolocation', engine, index=False, index_label='zip_code_prefix', if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_items.to_sql('order_items', engine, index=False, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_payments.to_sql('order_payments', engine, index=False, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
order_reviews.to_sql('order_reviews', engine, index=False, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
product_category_name_translation.to_sql('product_category_name_translation', engine, index=False, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sellers.to_sql('sellers', engine,index=False, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
products.to_sql('products', engine,index=False, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
orders.to_sql('orders', engine,index=False, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
calendario.to_sql('calendar', engine, index=False, if_exists='replace')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Creación de claves primarias y foráneas

# %%
CP_geolocation = "ALTER TABLE mydb.geolocation MODIFY COLUMN zip_code_prefix INT NOT NULL, MODIFY COLUMN latitude DOUBLE NULL DEFAULT NULL, MODIFY COLUMN longitude DOUBLE NULL DEFAULT NULL, MODIFY COLUMN city TEXT NULL DEFAULT NULL, MODIFY COLUMN state TEXT NULL DEFAULT NULL, MODIFY COLUMN Region TEXT NULL DEFAULT NULL, ADD PRIMARY KEY (zip_code_prefix)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_geolocation)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[830]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa089ed5af0&gt;</div>

# %%
CP_sellers= "ALTER TABLE mydb.sellers MODIFY COLUMN seller_id VARCHAR(40) NOT NULL, MODIFY COLUMN zip_code_prefix INT NULL DEFAULT NULL, MODIFY COLUMN city TEXT NULL DEFAULT NULL, MODIFY COLUMN state TEXT NULL DEFAULT NULL, ADD PRIMARY KEY (seller_id)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_sellers)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[832]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa0873d7160&gt;</div>

# %%
engine.execute("ALTER TABLE mydb.sellers ADD INDEX(zip_code_prefix)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[833]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa08a859c10&gt;</div>

# %%
engine.execute("SET FOREIGN_KEY_CHECKS=0")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[834]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa0873d7c10&gt;</div>

# %%
CF_sellers= "ALTER TABLE mydb.sellers ADD CONSTRAINT sellers_FK FOREIGN KEY (zip_code_prefix) REFERENCES mydb.geolocation(zip_code_prefix)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CF_sellers)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[836]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa08a859520&gt;</div>

# %%
CP_product_category_name_translation= "ALTER TABLE mydb.product_category_name_translation MODIFY COLUMN product_category_name VARCHAR(40) NOT NULL, MODIFY COLUMN product_category_name_english VARCHAR(40) NOT NULL, MODIFY COLUMN product_category_name_spanish VARCHAR(40) NOT NULL, ADD PRIMARY KEY (product_category_name)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_product_category_name_translation)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[838]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa091867ac0&gt;</div>

# %%
CP_order_reviews= "ALTER TABLE mydb.order_reviews MODIFY COLUMN review_id VARCHAR(40) NOT NULL, MODIFY COLUMN order_id VARCHAR(40) NULL DEFAULT NULL, MODIFY COLUMN review_score INT NULL DEFAULT NULL, MODIFY COLUMN comment_title VARCHAR(40) NULL DEFAULT NULL, MODIFY COLUMN comment_message VARCHAR(40) NULL DEFAULT NULL, MODIFY COLUMN creation_date DATETIME NULL DEFAULT NULL, MODIFY COLUMN answer_timestamp DATETIME NULL DEFAULT NULL, ADD PRIMARY KEY (review_id)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_order_reviews)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[840]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa086f37b20&gt;</div>

# %%
engine.execute("ALTER TABLE mydb.order_reviews ADD INDEX(order_id)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[841]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa08a859eb0&gt;</div>

# %%
CP_customers= "ALTER TABLE mydb.customers MODIFY COLUMN customer_id VARCHAR(40) NOT NULL, MODIFY COLUMN zip_code_prefix INT NULL DEFAULT NULL, MODIFY COLUMN city VARCHAR(40) NULL DEFAULT NULL, MODIFY COLUMN state VARCHAR(40) NULL DEFAULT NULL, ADD PRIMARY KEY (customer_id)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_customers)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[843]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa089ed5280&gt;</div>

# %%
CP_order_payments= "ALTER TABLE mydb.order_payments MODIFY COLUMN order_id VARCHAR(40) NULL DEFAULT NULL, MODIFY COLUMN payment_type VARCHAR(40) NULL DEFAULT NULL, MODIFY COLUMN payment_installments INT NULL DEFAULT NULL, MODIFY COLUMN payment_value DOUBLE NULL DEFAULT NULL, ADD PRIMARY KEY (payment_id)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_order_payments)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[845]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa07f18ba60&gt;</div>

# %%
engine.execute("ALTER TABLE mydb.order_payments ADD INDEX(order_id)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[846]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa089ed5850&gt;</div>

# %%
CP_products= "ALTER TABLE mydb.products MODIFY COLUMN product_id VARCHAR(40) NOT NULL,MODIFY COLUMN product_category_name VARCHAR(255) NULL DEFAULT NULL,MODIFY COLUMN name_length INT NULL DEFAULT NULL,MODIFY COLUMN description_length INT NULL DEFAULT NULL,MODIFY COLUMN photos_quantity INT NULL DEFAULT NULL,MODIFY COLUMN weight_g DOUBLE NULL DEFAULT NULL,MODIFY COLUMN length_cm DOUBLE NULL DEFAULT NULL,MODIFY COLUMN height_cm DOUBLE NULL DEFAULT NULL,MODIFY COLUMN width_cm DOUBLE NULL DEFAULT NULL,ADD PRIMARY KEY (product_id)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_products)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[848]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa08a859d90&gt;</div>

# %%
engine.execute("ALTER TABLE mydb.products ADD INDEX(product_category_name)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[849]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa08a50e370&gt;</div>

# %%
CP_order_items="ALTER TABLE mydb.order_items MODIFY COLUMN order_id VARCHAR(40) NOT NULL,MODIFY COLUMN product_quantity INT NULL DEFAULT NULL,MODIFY COLUMN product_id VARCHAR(40) NULL DEFAULT NULL,MODIFY COLUMN seller_id VARCHAR(40) NULL DEFAULT NULL,MODIFY COLUMN shipping_limit_date DATETIME NULL DEFAULT NULL,MODIFY COLUMN price DOUBLE NULL DEFAULT NULL,MODIFY COLUMN freight_value DOUBLE NULL DEFAULT NULL,ADD PRIMARY KEY (order_id)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_order_items)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[851]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa086f37d30&gt;</div>

# %%
engine.execute("ALTER TABLE mydb.order_items ADD INDEX(product_id),ADD INDEX(seller_id)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[852]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa08a859d60&gt;</div>

# %%
CF_products="ALTER TABLE mydb.products ADD CONSTRAINT products_FK FOREIGN KEY (product_category_name) REFERENCES mydb.product_category_name_translation(product_category_name)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CF_products)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[854]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa089ed5880&gt;</div>

# %%
CP_orders = "ALTER TABLE mydb.orders MODIFY COLUMN order_id VARCHAR(40) NOT NULL,MODIFY COLUMN customer_id VARCHAR(40) NULL DEFAULT NULL,MODIFY COLUMN order_status VARCHAR(40) NULL DEFAULT NULL,MODIFY COLUMN purchase_timestamp DATETIME NULL DEFAULT NULL,MODIFY COLUMN order_approved_at DATETIME NULL DEFAULT NULL,MODIFY COLUMN delivered_carrier_date DATETIME NULL DEFAULT NULL,MODIFY COLUMN delivered_customer_date DATETIME NULL DEFAULT NULL, MODIFY COLUMN estimated_delivery_date DATETIME NULL DEFAULT NULL,ADD PRIMARY KEY(order_id)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CP_orders)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[856]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa08a33a160&gt;</div>

# %%
CF_orders_customers="ALTER TABLE mydb.orders ADD CONSTRAINT orders_FK FOREIGN KEY (customer_id) REFERENCES mydb.customers(customer_id)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
engine.execute(CF_orders_customers)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[858]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa089ed5d00&gt;</div>

# %%
engine.execute("ALTER TABLE mydb.orders ADD INDEX(customer_id),ADD INDEX(purchase_timestamp)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[859]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa087fa4ca0&gt;</div>

# %%
engine.execute("ALTER TABLE mydb.order_items ADD CONSTRAINT order_items_FK_1 FOREIGN KEY (seller_id) REFERENCES mydb.sellers(seller_id)")
engine.execute("ALTER TABLE mydb.order_items ADD CONSTRAINT order_items_FK_2 FOREIGN KEY (product_id) REFERENCES mydb.products(product_id)")
engine.execute("ALTER TABLE mydb.order_items ADD CONSTRAINT order_items_FK_3 FOREIGN KEY (order_id) REFERENCES mydb.orders(order_id)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[860]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa0812ffd60&gt;</div>

# %%
engine.execute("ALTER TABLE mydb.order_payments ADD CONSTRAINT order_payments_FK FOREIGN KEY (order_id) REFERENCES mydb.order_items(order_id)")
engine.execute("ALTER TABLE mydb.order_reviews ADD CONSTRAINT order_reviews_FK FOREIGN KEY (order_id) REFERENCES mydb.orders(order_id)")
engine.execute("ALTER TABLE mydb.calendar ADD CONSTRAINT calendar_PK PRIMARY KEY (`date`)")
engine.execute("ALTER TABLE mydb.orders ADD CONSTRAINT orders_FK_1 FOREIGN KEY (purchase_timestamp) REFERENCES mydb.calendar(`date`)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[861]: &lt;sqlalchemy.engine.cursor.LegacyCursorResult at 0x7fa0900b2f70&gt;</div>
