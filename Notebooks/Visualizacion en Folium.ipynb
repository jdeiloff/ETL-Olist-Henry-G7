# %% [markdown]
# # Requisitos

# %% [markdown]
# ## Instalación de librerías requeridas.

# %%
# %pip install PyMySQL
# %pip install deep_translator
# %pip install boto3
# %pip install sdv
# %pip install sqlalchemy
# %pip install folium
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# ...

# %% [markdown]
# ## Importación de librerías requeridas

# %%
import pandas as pd
import numpy as np
import requests
from sqlalchemy import create_engine

import datetime as dt

import plotly as plt
import plotly.graph_objects as go
import plotly.express as px

import folium
from folium.plugins import MarkerCluster
import os
from folium.plugins import MiniMap
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Ingestar los datos necesarios

# %% [markdown]
# ## Conexión a la DB y generación de dataframes

# %%
engine = create_engine('mysql+pymysql://sojoclar:sojoclar@proyecto-grupal-henry.cy2mi1kbmfb7.us-east-2.rds.amazonaws.com:3306/mydb')
customers = pd.read_sql_table('customers', engine)
geolocation=pd.read_sql_table('geolocation', engine)
order_items=pd.read_sql_table('order_items', engine)
order_payments=pd.read_sql_table('order_payments', engine)
order_reviews=pd.read_sql_table('order_reviews', engine)
orders=pd.read_sql_table('orders', engine)
products=pd.read_sql_table('products', engine)
sellers=pd.read_sql_table('sellers', engine)
product_category_name_translation=pd.read_sql_table('product_category_name_translation', engine)
calendar=pd.read_sql_table('calendar',engine)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Uniones de dataframes

# %%
df_exp=pd.merge(orders, order_reviews , on='order_id', how='inner')
df_exp=pd.merge(df_exp, customers , on='customer_id', how='inner')
df_exp=pd.merge(df_exp,order_items,on='order_id',how='inner')
df_exp=pd.merge(df_exp,products,on='product_id',how='inner')
df_exp=pd.merge(df_exp,geolocation,on='zip_code_prefix',how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_exp.latitude.fillna(0)
df_exp.longitude.fillna(0)
# Out:
# Out[20]: 0       -41.312633
# 1       -41.312633
# 2       -41.312633
# 3       -41.312633
# 4       -41.312633
#            ...
# 97407   -37.766817
# 97408   -44.048033
# 97409   -59.921575
# 97410   -35.759936
# 97411   -38.179823
# Name: longitude, Length: 97412, dtype: float64

# %%
cf.set_config_file(sharing='public',theme='ggplot',offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
productos_grafica= df_exp.groupby('product_category_name').count()
productos_graf=productos_grafica['product_id'].sort_values(ascending=False).head(9)

# %%
productos_graf.iplot(kind='bar',xTitle='Dias',title='Invertir segun el dia',)

# %%
feature_group_active = folium.FeatureGroup(name='Active')
feature_group_unactive = folium.FeatureGroup(name='Unactive')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
map_clusters = folium.Map(location=[-15.89, -47.9], zoom_start=11)
# add markers to the map
marker_cluster_active = MarkerCluster()
marker_cluster_unactive =MarkerCluster()
for i in range (len(df_exp['latitude'])):
    if(df_exp["review_score"][i]>3):
        marker_active = folium.Marker(location=[df_exp['latitude'][i],df_exp['longitude'][i]],popup=df_exp['product_category_name'][i],icon = folium.Icon(color='green',icon='ok-sign'))
        marker_cluster_active.add_child(marker_active)
    else:
        marker_unactive = folium.Marker(location=[df_exp['latitude'][i],df_exp['longitude'][i]],popup=df_exp['product_category_name'][i],icon = folium.Icon(color='red',icon='exclamation-sign'))
        marker_cluster_unactive.add_child(marker_unactive)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
feature_group_active.add_child(marker_cluster_active)
feature_group_unactive.add_child(marker_cluster_unactive)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: &lt;folium.map.FeatureGroup at 0x7f634425f3d0&gt;</div>

# %%
map_clusters.add_child(feature_group_active)
map_clusters.add_child(feature_group_unactive)

# %%
map_clusters.save('mapa2.html')

# %%
import folium
from folium.plugins import MarkerCluster


m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)


folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)
m
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: </div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
m = folium.map(location=[-23.549292,-46.633559])

# %%
df_exp[df_exp['latitude'].isnull()]

# %%
m = folium.Map(location=[-23.549292,-46.633559])
for i in df_exp.itertuples():
    folium.Marker(location=[df_exp.latitude,df_exp.longitude],popup=folium.Popup(df_exp.city_y,max_width=200).add_to(m))

# %%
# Calculate average three point field goal percentage by position
positions = df_exp.groupby("product_category_name", as_index=False).count()

# Instantiate figure
fig = figure(x_axis_label="productos", y_axis_label="cantidad", x_range=positions["product_category_name"]) 

# Add bars
fig.vbar(x=positions["product_category_name"])

# Produce the html file and display the plot
# output_file(filename="3p_fg_by_position.html")
show(fig)

# %%
df_exp['product_category_name'].value_counts()
